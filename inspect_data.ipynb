# %%
import numpy as np

mel_spectogram = np.load('/Volumes/SamsungT7/AMGCDataset/00/1002000.npy')

# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display

# ax[0].set(title = 'Mel Spectrogram of R&B')
librosa.display.specshow(mel_spectogram, cmap = 'magma')
# plt.plot(mel_spectogram)
